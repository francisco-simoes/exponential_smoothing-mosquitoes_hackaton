# %%
import pandas as pd

# %%
pd.DataFrame( [['add', 'add', 6, 11.94],[],[],[],[],[],[],[]], columns=['trend', 'seasonal', 'seasonal periods','sqrt(MSE)'])
# Out:
#   trend seasonal  seasonal periods  sqrt(MSE)
# 0   add      add               6.0      11.94
# 1  None     None               NaN        NaN
# 2  None     None               NaN        NaN
# 3  None     None               NaN        NaN
# 4  None     None               NaN        NaN
# 5  None     None               NaN        NaN
# 6  None     None               NaN        NaN
# 7  None     None               NaN        NaN
